# %%
from snake_ladder import SnakeLadder

# %%
env = SnakeLadder(max_steps=15)

# %%
env.reset()
# Out:
# 0

# %%
env.render()
# Out:
# Current state: 0
# In Step: 0 of 15 steps

# %%
go = 4
env.step(go-1, True)
# Out:
# Current state: 75
# In Step: 1 of 15 steps
# (75, False, 0)

# %%
go = 5
env.step(go-1, True)
# Out:
# Current state: 80
# In Step: 2 of 15 steps
# (80, False, 0)

# %%
go = 6
env.step(go-1, True)
# Out:
# Current state: 86
# In Step: 3 of 15 steps
# (86, False, 0)

# %%
go = 6
env.step(go-1, True)
# Out:
# Current state: 92
# In Step: 4 of 15 steps
# (92, False, 0)

# %%
go = 5
env.step(go-1, True)
# Out:
# Current state: 97
# In Step: 5 of 15 steps
# (97, False, 0)

# %%
go = 3
env.step(go-1, True)
# Out:
# Current state: 100 , Message: Winner!
# In Step: 6 of 15 steps
# (100, True, 0.4)
