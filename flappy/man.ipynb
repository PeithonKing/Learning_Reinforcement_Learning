# %%
import numpy as np
import random
import time
from flappy_bird import FlappyBirds
from tqdm import tqdm

# %%
nx, ny = 10, 10
env1 = FlappyBirds(nx = nx, ny = ny, g = 2)
env2 = FlappyBirds(nx = nx, ny = ny, g = 2)

# %%
env1.step(0)
# Out:
# (8, -1, 5, False, 0)

# %%
env2.step(0)
# Out:
# (1, 25, 18, False, 0)

# %%
env1.render()
# Out:
# .  .  .  .  .  .  .  .  O  .
# .  .  .  .  .  .  .  .  O  .
# .  .  .  .  .  .  .  .  O  .
# .  .  .  .  .  .  .  .  .  .
# .  .  .  .  .  .  .  .  .  .
# B  .  .  .  .  .  .  .  .  .
# .  .  .  .  .  .  .  .  O  .
# .  .  .  .  .  .  .  .  O  .
# .  .  .  .  .  .  .  .  O  .
# .  .  .  .  .  .  .  .  O  .

# %%
env2.step(1)
# Out:
# (2, 20, 23, False, 0)
